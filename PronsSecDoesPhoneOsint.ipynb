# %% [markdown]
# <a href="https://colab.research.google.com/github/pronsSec/PronsSecDoesPhoneOsint/blob/main/PronsSecDoesPhoneOsint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome Yo
#
#
# ---
#
#
# >It sounds like someone may be calling/texting you and you have some questions..
#
# >Well here is a pretty ok tool to start that journey. You will be able to gather Region, Timezone, and (sometimes) Carrier information on that number! **This is not live info, it is from the time of line creation.**
#
#
# >Carrier info will vary, and it may often be blank. Most major carriers in the US and Europe will not be shown. But, the carriers that spammers often use WILL often have results. This generally applies to Vodafone etc.
#
# >This tool will be updated to include some more in-depth information regarding the numbers soon... but for now... enjoy!
#
# Work from top to bottom and follow the instructions!
#
# >P.S. - Here is a test number and also the format to follow when inputting your numbers:  +40721234567
#
#
#
#
# ---
#
#
#
# -been
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---

# %%
#@title Press Play Here Once Per Session to Install Packages { display-mode: "form" }
#@markdown ---
#@markdown You can then search multiple numbers in the second block
# !pip install pyfiglet
# !pip install phonenumbers
# !pip install colorama 
import os
import time
import pyfiglet
import phonenumbers 
from colorama import Fore 
from datetime import datetime   
from phonenumbers import geocoder 
from phonenumbers import carrier
from phonenumbers import timezone
from IPython.display import clear_output
clear_output()
done = pyfiglet.figlet_format("All Good\n ------------- \n Rerun this block if your page refreshes.")
print(done)

# %%
#@title Enter The Number Here 


#@markdown ---




#@markdown (11 digits max including country code and then add "+" in front) { display-mode: "form" }
\
#@markdown ---


#def. variables
def run():
  l = "------------------"
  t = time.sleep

  result = pyfiglet.figlet_format("PronsSec \\\\\\\\ Phone Number OSINT \\\\\\")
  print(result)

  print(l)


  t(0.3)
  t(2)

  now = datetime.now()

  current_time = now.strftime("%H:%M:%S")
  print("Current Time =", current_time)
  t(2)

  number = "" #@param {type: "string"}
  #@markdown ---
  #@markdown Then Press Play


  #@markdown ---



  t(1)

  #See if the numbers valid 
  ch_nmber = phonenumbers.parse(number)
  print("Is This a Real Number: ") 
  print(phonenumbers.is_possible_number(ch_nmber))
  print(l)
  t(0.5)

  #Find their state
  ch_nmber = phonenumbers.parse(number, "CH")
  print("State/Region: ")
  print(geocoder.description_for_number(ch_nmber, "en"))
  print(l)
  t(0.5)

  #Find their carrier (Still in Development)
  ch_nmber = phonenumbers.parse(number, "CH")
  print("Carrier Name: ")
  print(carrier.name_for_number(ch_nmber, "en"))
  print(l)
  t(0.5)

  #Find their time zone 
  ch_nmber = phonenumbers.parse(number)
  print("Timezone: ")
  print(timezone.time_zones_for_number(ch_nmber))
  print(l)
  t(0.5)
  result = pyfiglet.figlet_format("Enjoy")
  print(result)
  print(l)

  service_nmber = phonenumbers.parse(number, "CH")

try:
  run()
except:
  clear_output()
  result_error = pyfiglet.figlet_format('Oops something went wrong!')
  print(result_error)
  print('Check your phone number input... It should be 11 digits max with a plus sign in front...no spaces and hyphens.')
  print("-"*50)
  print('If all else fails just refresh the page and run both blocks again!')
